# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaytonSdS/Pi-Calculator/blob/main/Google_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
import pandas as pd

time_1 = '08:26'
time_2 = '18:26'

t1 = datetime.strptime(time_1, "%H:%M")
t2 = datetime.strptime(time_2, "%H:%M")

delta = (t2 - t1).total_seconds()

# %%
data =  pd.read_csv('personal_uber_driver_data.csv', sep=";", quotechar='"')

# %%
data
# Out:
#                           date ride_starting_time  \
# 0      Monday, June 12th, 2023              07:36
# 1      Monday, June 12th, 2023              11:26
# 2      Monday, June 12th, 2023              11:40
# 3      Monday, June 12th, 2023              12:12
# 4      Monday, June 12th, 2023              17:03
# 5     Tuesday, June 13th, 2023              07:23
# 6     Tuesday, June 13th, 2023              07:40
# 7     Tuesday, June 13th, 2023              09:28
# 8     Tuesday, June 13th, 2023              11:20
# 9     Tuesday, June 13th, 2023              11:20
# 10    Tuesday, June 13th, 2023              12:28
# 11    Tuesday, June 13th, 2023              14:12
# 12    Tuesday, June 13th, 2023              14:59
# 13    Tuesday, June 13th, 2023              16:12
# 14    Tuesday, June 13th, 2023              16:49
# 15    Tuesday, June 13th, 2023              17:28
# 16  Wednesday, June 14th, 2023              07:19
# 17  Wednesday, June 14th, 2023              07:37
# ...

# %%
data["mean_velocity"] = data['distance']/data['duration'] * 3.6

# %%
data
# Out:
#                           date ride_starting_time  \
# 0      Monday, June 12th, 2023              07:36
# 1      Monday, June 12th, 2023              11:26
# 2      Monday, June 12th, 2023              11:40
# 3      Monday, June 12th, 2023              12:12
# 4      Monday, June 12th, 2023              17:03
# 5     Tuesday, June 13th, 2023              07:23
# 6     Tuesday, June 13th, 2023              07:40
# 7     Tuesday, June 13th, 2023              09:28
# 8     Tuesday, June 13th, 2023              11:20
# 9     Tuesday, June 13th, 2023              11:20
# 10    Tuesday, June 13th, 2023              12:28
# 11    Tuesday, June 13th, 2023              14:12
# 12    Tuesday, June 13th, 2023              14:59
# 13    Tuesday, June 13th, 2023              16:12
# 14    Tuesday, June 13th, 2023              16:49
# 15    Tuesday, June 13th, 2023              17:28
# 16  Wednesday, June 14th, 2023              07:19
# 17  Wednesday, June 14th, 2023              07:37
# ...
